# %% [markdown]
# # Passerio Aleatório

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from random import sample, random

# %%
dados = sample(range(100), k=41) # 41 Valores, entre 0 e 100
dados
# Out:
# [50,
#  63,
#  52,
#  74,
#  67,
#  55,
#  86,
#  72,
#  30,
#  25,
#  75,
#  7,
#  29,
#  80,
#  13,
#  92,
#  85,
#  5,
#  3,
#  82,
#  9,
#  18,
#  84,
#  54,
#  4,
#  89,
#  68,
#  36,
#  46,
#  57,
#  37,
#  66,
#  8,
#  95,
#  24,
#  10,
#  32,
#  47,
#  20,
#  1,
#  56]

# %%
anos = list(range(1980,2021))
anos
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
serie = pd.Series(dados, index = anos)

# %%
serie.plot()
plt.show() # Sem coerência de repetição, um passeio aleatório.

# %%
serie2 = list()
serie2.append(-1 if random() < 0.5 else 1)
print(serie2)
for i in range(1 , 1000):
    movimento = -1 if random() < 0.5 else 1
    valor = serie2[i-1] + movimento #
    serie2.append(valor)
    print(f'O movimento será {movimento} \n O valor será {serie2[i-1]} + {movimento}')
    print(serie2)
# Out:
# [-1]
# O movimento será -1
#  O valor será -1 + -1
# [-1, -2]
# O movimento será 1
#  O valor será -2 + 1
# [-1, -2, -1]
# O movimento será -1
#  O valor será -1 + -1
# [-1, -2, -1, -2]
# O movimento será 1
#  O valor será -2 + 1
# [-1, -2, -1, -2, -1]
# O movimento será -1
#  O valor será -1 + -1
# [-1, -2, -1, -2, -1, -2]
# O movimento será -1
#  O valor será -2 + -1
# [-1, -2, -1, -2, -1, -2, -3]
# O movimento será -1
#  O valor será -3 + -1
# [-1, -2, -1, -2, -1, -2, -3, -4]
# O movimento será -1
#  O valor será -4 + -1
# [-1, -2, -1, -2, -1, -2, -3, -4, -5]
# O movimento será -1
#  O valor será -5 + -1
# [-1, -2, -1, -2, -1, -2, -3, -4, -5, -6]
# O movimento será 1
#  O valor será -6 + 1
# [-1, -2, -1, -2, -1, -2, -3, -4, -5, -6, -5]
# O movimento será 1
#  O valor será -5 + 1
# [-1, -2, -1, -2, -1, -2, -3, -4, -5, -6, -5, -4]
# O movimento será 1
#  O valor será -4 + 1
# [-1, -2, -1, -2, -1, -2, -3, -4, -5, -6, -5, -4, -3]
# O movimento será 1
#  O valor será -3 + 1
# ...

# %%
serie2 = pd.Series(serie2)

# %%
serie2.plot()
plt.show()
